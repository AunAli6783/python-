# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("datasaurus.csv")
df
# Out:
#          dataset          x          y
# 0           dino  55.384600  97.179500
# 1           dino  51.538500  96.025600
# 2           dino  46.153800  94.487200
# 3           dino  42.820500  91.410300
# 4           dino  40.769200  88.333300
# ...          ...        ...        ...
# 1841  wide_lines  33.674442  26.090490
# 1842  wide_lines  75.627255  37.128752
# 1843  wide_lines  40.610125  89.136240
# 1844  wide_lines  39.114366  96.481751
# 1845  wide_lines  34.583829  89.588902
#
# [1846 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1846 entries, 0 to 1845
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  1846 non-null   object
#  1   x        1846 non-null   float64
#  2   y        1846 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 43.4+ KB

# %%
df.describe()
# Out:
#                  x            y
# count  1846.000000  1846.000000
# mean     54.265695    47.835099
# std      16.713001    26.847766
# min      15.560750     0.015119
# 25%      41.073403    22.561073
# 50%      52.591269    47.594450
# 75%      67.277845    71.810778
# max      98.288123    99.694680

# %%
df.isnull().sum()
# Out:
# dataset    0
# x          0
# y          0
# dtype: int64

# %%
sns.lineplot(data=df,x=df['x'],y=df['y'])
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.histplot(data=df ,x=df['x'], y=df['y'], color='blue', hue=True , kde=True)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.barplot(data=df,x=df['x'],y=df['y'])
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.kdeplot(data=df,x=df['x'],y=df['y'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('dinasaurous')
plt.show()

# %%
sns.pairplot(data=df)

# %%
sns.displot(data=df )

# %%
plt.plot(df['x'], df['y'])

# %%
plt.hist(df['x'], bins=10)
# Out:
# (array([ 28., 173., 238., 221., 404., 246., 268., 181.,  58.,  29.]),
#  array([15.56074952, 23.8334869 , 32.10622427, 40.37896165, 48.65169902,
#         56.9244364 , 65.19717377, 73.46991115, 81.74264852, 90.0153859 ,
#         98.28812327]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['x'], df['y'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['dataset']=le.fit_transform(df['dataset'])
df
# Out:
#       dataset          x          y
# 0           3  55.384600  97.179500
# 1           3  51.538500  96.025600
# 2           3  46.153800  94.487200
# 3           3  42.820500  91.410300
# 4           3  40.769200  88.333300
# ...       ...        ...        ...
# 1841       11  33.674442  26.090490
# 1842       11  75.627255  37.128752
# 1843       11  40.610125  89.136240
# 1844       11  39.114366  96.481751
# 1845       11  34.583829  89.588902
#
# [1846 rows x 3 columns]

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1841    False
# 1842    False
# 1843    False
# 1844    False
# 1845    False
# Length: 1846, dtype: bool

# %%
# Out:
# <bound method DataFrame.rename of       dataset          x          y
# 0           3  55.384600  97.179500
# 1           3  51.538500  96.025600
# 2           3  46.153800  94.487200
# 3           3  42.820500  91.410300
# 4           3  40.769200  88.333300
# ...       ...        ...        ...
# 1841       11  33.674442  26.090490
# 1842       11  75.627255  37.128752
# 1843       11  40.610125  89.136240
# 1844       11  39.114366  96.481751
# 1845       11  34.583829  89.588902
#
# [1846 rows x 3 columns]>
